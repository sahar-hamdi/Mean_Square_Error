# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1- Plot the points and Lines: #

# %%
x = np.array([2 , 4 , 6 , 8 , 10 , 12])
y = np.array([5 , 6 , 6 , 8 , 5 , 12])

# %%
y1 = x 
y2 = 1 / 2 * x 
y3 = 1 / 2 * x + 4

# %%
plt.plot(x , y1)
plt.plot(x , y2)
plt.plot(x , y3)

plt.scatter(x , y)
plt.show()

# %% [markdown]
# # 2- Calculate the cost Function for each case: #

# %%
#Case1 using numpy:
x = np.array([2 , 4 , 6 , 8 , 10 , 12])
y = np.array([5 , 6 , 6 , 8 , 5 , 12])
y1 = x

meanSquareError1 = np.square(np.subtract(y1 , y)).mean()
print("The Cost Function for the first case = " , meanSquareError)
# Out:
# The Cost Function for the first case =  6.333333333333333

# %%
plt.plot(x , y1)
plt.scatter(x , y1 , color = 'r')
plt.show()

# %%
#Case1 using loop:
x = np.array([2 , 4 , 6 , 8 , 10 , 12])
y = np.array([5 , 6 , 6 , 8 , 5 , 12])
y1 = x
m = 6
summation = 0 ;
for i in range(0 , m):
    diff = y1 - y[i]
    diffsquare = diff ** 2
    summation += diffsquare
meanSquarError1 = summation / m 
print("The Cost Function for the first case = " , meanSquareError)
# Out:
# The Cost Function for the first case =  6.333333333333333

# %%
#Case2 using numpy:
x = np.array([2 , 4 , 6 , 8 , 10 , 12])
y = np.array([5 , 6 , 6 , 8 , 5 , 12])
y2 = 0.5 * x

meanSquareError2 = np.square(np.subtract(y2 , y)).mean()
print("The Cost Function for the first case = " , meanSquareError)
# Out:
# The Cost Function for the first case =  6.333333333333333

# %%
plt.plot(x , y2)
plt.scatter(x , y2 , color = 'g')
plt.show()

# %%
#Case3 using numpy:
x = np.array([2 , 4 , 6 , 8 , 10 , 12])
y = np.array([5 , 6 , 6 , 8 , 5 , 12])
y3 = 0.5 * x + 4

meanSquareError3 = np.square(np.subtract(y3 , y)).mean()
print("The Cost Function for the first case = " , meanSquareError)
# Out:
# The Cost Function for the first case =  6.333333333333333

# %%
plt.plot(x , y3)
plt.scatter(x , y3 , color = 'y')
plt.show()

# %% [markdown]
# # 3D Scatter w , b , j(w , b): #

# %%
w = np.array([1 , 0.5 , 0.5])
b = np.array([0 , 0 , 4])
cost_function = np.array([meanSquareError1 , meanSquareError2 , meanSquareError3])

# %%
fig = plt.figure(figsize = (10 , 7))
ax = plt.axes(projection = '3d')
ax.plot(w , b , cost_function , color = 'r')
plt.title('3D Scatter to plot w , b and j(w , b)')
ax.set_xlabel("w")
ax.set_ylabel("b")
ax.set_zlabel("j(w , b)")
plt.show()
